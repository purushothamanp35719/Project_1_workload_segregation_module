# %%
import logging

logger = basicConfig(level=logging.INFO,
                     format=%(asctime)s-%(levelname)s-%(name)s-%(message)s)

logger.getLogger("Data Pipeline")

logger.info("Started...")
                    
print("Hello Purushothaman")
print("Hello Purushothaman")
print("Hello Purushothaman")

logger.info("Completed...")
